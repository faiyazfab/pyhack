# %% [markdown]
# <a href="https://colab.research.google.com/github/faiyazfab/pyhack/blob/main/pyhack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib3
import requests
import certifi
import json
import pandas as pd

# %%
r_ae = requests.get('https://pyhack-dot-pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/ae/subject/list')
d=pd.DataFrame(r_ae.json())
print(d)
# Out:
#       status      data                            request_id
# 0    success     76809  b7fcb3d5-7c35-4a9f-b54f-3dae8bc41565
# 1    success    105792  b7fcb3d5-7c35-4a9f-b54f-3dae8bc41565
# 2    success    117691  b7fcb3d5-7c35-4a9f-b54f-3dae8bc41565
# 3    success    120205  b7fcb3d5-7c35-4a9f-b54f-3dae8bc41565
# 4    success    130301  b7fcb3d5-7c35-4a9f-b54f-3dae8bc41565
# ..       ...       ...                                   ...
# 723  success  17954820  b7fcb3d5-7c35-4a9f-b54f-3dae8bc41565
# 724  success  17956076  b7fcb3d5-7c35-4a9f-b54f-3dae8bc41565
# 725  success  18042999  b7fcb3d5-7c35-4a9f-b54f-3dae8bc41565
# 726  success  18282353  b7fcb3d5-7c35-4a9f-b54f-3dae8bc41565
# 727  success  18291148  b7fcb3d5-7c35-4a9f-b54f-3dae8bc41565
#
# [728 rows x 3 columns]

# %%
r_cm= requests.get('https://pyhack-dot-pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/cm/subject/list')
dd=pd.DataFrame(r_cm.json())
print(dd)
# Out:
#       status      data                            request_id
# 0    success     76809  d21e6c0e-b168-451e-ae75-028d6ac44881
# 1    success    130301  d21e6c0e-b168-451e-ae75-028d6ac44881
# 2    success    132645  d21e6c0e-b168-451e-ae75-028d6ac44881
# 3    success    138700  d21e6c0e-b168-451e-ae75-028d6ac44881
# 4    success    166621  d21e6c0e-b168-451e-ae75-028d6ac44881
# ..       ...       ...                                   ...
# 717  success  55325218  d21e6c0e-b168-451e-ae75-028d6ac44881
# 718  success  55334564  d21e6c0e-b168-451e-ae75-028d6ac44881
# 719  success  55392353  d21e6c0e-b168-451e-ae75-028d6ac44881
# 720  success  55396342  d21e6c0e-b168-451e-ae75-028d6ac44881
# 721  success  55397989  d21e6c0e-b168-451e-ae75-028d6ac44881
#
# [722 rows x 3 columns]

# %%
for i in range(len(dd)):
  response_cm_data =requests.get('https://pyhack-dot-pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/cm/subject/{}/list'.format(dd['data'][i]))
  response_cm_data = response_cm_data.json()
  per_record = pd.DataFrame(response_cm_data['data'])
  #type1
  type1 = per_record[per_record['cmprior']=='YES'][['subjectid','formidx','formname','formid']]
  print("____________________________________________type 1____________________________________________________")
  for j in range(len(type1)):
            formid = list(type1['formid'])[j]
            formidx = list(type1['formidx'])[j]
            formname = list(type1['formname'])[j]
            subjectid = list(type1['subjectid'])[j]
            print(formidx,subjectid,formname,formid)
            postReq={
                  "email_address": "faiyazfab5800@gmail.com",
                  "formname": "str(formname)",
                  "formid": "str(formid)",
                  "formidx": "str(formidx)",
                  "type": "TYPE1",
                  "subjectid": "str(data)"
                    }
            post=requests.post('https://pyhack-dot-pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/query', data = postReq)
            print(post)
    
    
  #Type2
  type2 = per_record[per_record['cmaeno']!='0'][['subjectid','formidx','formname','formid']]
  print("____________________________________________type 2____________________________________________________")
  for q in range(len(type2)):
            formid = list(type2['formid'])[q]
            formidx = list(type2['formidx'])[q]
            formname = list(type2['formname'])[q]
            subjectid = list(type2['subjectid'])[q]
            print(formidx,subjectid,formname,formid)
            postReq={
                  "email_address": "faiyazfab5800@gmail.com",
                  "formname": "str(formname)",
                  "formid": "str(formid)",
                  "formidx": "str(formidx)",
                  "type": "TYPE1",
                  "subjectid": "str(data)"
                    }
            post2=requests.post('https://pyhack-dot-pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/query', data = postReq)
            print(post2)
  #type4
  type4 = per_record[['cmtrt','subjectid','formidx','formname','formid']]
  print("____________________________________________type 4____________________________________________________")
  for e in range(len(type4)-1):
      if (list(per_record['cmtrt'])[e] == list(per_record['cmtrt'])[e+1]):
            formid = list(type4['formid'])[e]
            formidx = list(type4['formidx'])[e]
            formname = list(type4['formname'])[e]
            subjectid = list(type4['subjectid'])[e]
            print(formidx,subjectid,formname,formid)
            postReq={
                  "email_address": "faiyazfab5800@gmail.com",
                  "formname": "str(formname)",
                  "formid": "str(formid)",
                  "formidx": "str(formidx)",
                  "type": "TYPE1",
                  "subjectid": "str(data)"
                    }
            post4=requests.post('https://pyhack-dot-pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/query', data = postReq)
            print(post4)
# Out:
# ____________________________________________type 1____________________________________________________
# 1 76809 CM201 38623
# <Response [500]>
# 2 76809 CM201 38623
# <Response [500]>
# 3 76809 CM201 38623
# <Response [500]>
# 4 76809 CM201 38623
# <Response [500]>
# 5 76809 CM201 38623
# <Response [500]>
# 6 76809 CM201 38623
# <Response [500]>
# 8 76809 CM201 38623
# <Response [500]>
# 9 76809 CM201 38623
# <Response [500]>
# 50 76809 CM201 38623
# <Response [500]>
# 17 76809 CM201 38623
# <Response [500]>
# 18 76809 CM201 38623
# <Response [500]>
# 19 76809 CM201 38623
# <Response [500]>
# 20 76809 CM201 38623
# <Response [500]>
# 21 76809 CM201 38623
# <Response [500]>
# 22 76809 CM201 38623
# <Response [500]>
# 30 76809 CM201 38623
# <Response [500]>
# 31 76809 CM201 38623
# <Response [500]>
# 42 76809 CM201 38623
# <Response [500]>
# ____________________________________________type 2____________________________________________________
# 76 76809 CM201 38623
# <Response [500]>
# ...

# %%
for i in range(len(d)):
  response_ae_data =requests.get('https://pyhack-dot-pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/ae/subject/{}/list'.format(d['data'][i]))
  response_ae_data = response_ae_data.json()
  per_record_ae = pd.DataFrame(response_ae_data['data'])
  #type3
  type3 = per_record_ae[['subjectid','formidx','formname','formid','aeterm']]
  for w in range(len(type3)-1):
      if (list(per_record_ae['aeterm'])[w] == list(per_record_ae['aeterm'])[w+1]):
            formid = list(type1['formid'])[w]
            formidx = list(type1['formidx'])[w]
            formname = list(type1['formname'])[w]
            subjectid = list(type1['subjectid'])[w]
            print(formidx,subjectid,formname,formid)
            postReq={
                  "email_address": "faiyazfab5800@gmail.com",
                  "formname": "str(formname)",
                  "formid": "str(formid)",
                  "formidx": "str(formidx)",
                  "type": "TYPE1",
                  "subjectid": "str(data)"
                    }
            post3=requests.post('https://pyhack-dot-pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/query', data = postReq)
            print(post3)
# Out:
# 50 130301 CM201 38623
# <Response [500]>
# 18 130301 CM201 38623
# <Response [500]>
# 19 130301 CM201 38623
# <Response [500]>
# 20 130301 CM201 38623
# <Response [500]>
# 22 130301 CM201 38623
# <Response [500]>
# 24 130301 CM201 38623
# <Response [500]>
# 30 130301 CM201 38623
# <Response [500]>
# 31 130301 CM201 38623
# <Response [500]>
# 39 130301 CM201 38623
# <Response [500]>
# 40 130301 CM201 38623
# <Response [500]>
# 45 130301 CM201 38623
# <Response [500]>
# 2 130301 CM201_3 32993
# <Response [500]>
# 4 130301 CM201_3 32993
# <Response [500]>
# 2 130301 CM201 38623
# <Response [500]>
# 3 130301 CM201 38623
# <Response [500]>
# 4 130301 CM201 38623
# <Response [500]>
# 6 130301 CM201 38623
# <Response [500]>
# 7 130301 CM201 38623
# <Response [500]>
# 8 130301 CM201 38623
# <Response [500]>
# 50 130301 CM201 38623
# <Response [500]>
# 52 130301 CM201 38623
# <Response [500]>
# 53 130301 CM201 38623
# <Response [500]>
# 24 130301 CM201 38623
# <Response [500]>
# ...
